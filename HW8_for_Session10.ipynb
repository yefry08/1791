# %% [markdown]
# <a href="https://colab.research.google.com/github/yefry08/1791/blob/main/HW8_for_Session10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homework 8: SQL
#
# After going through the lecture notebooks, work on the homework below.

# %% [markdown]
# ## Question
#
# This homework is quiz-style assignment.
#
# Choose the answer you think is correct, then write your answer in the code block below. Run all code blocks to generate `submission.csv`. Download the file, then submit to Omnicampus.
#
# **A score of 8 or more out of 10 is considered correct.**
#
# **Submission Guidelines:**<br>
# 1. Download your `submission.csv` from the folder icon on the left. Click the $\vdots$ button or right click the file to download.
#
# <img src="https://lh3.googleusercontent.com/d/1bBuSWk9ujoqpZzv7waGra1fToX0bhC6_" width="400"><br>
# <img src="https://lh3.googleusercontent.com/d/1gBbEbpHdlUtTJ0UgxPCM8n26V_GJVMPX" width="400">
#
# 2. Go to Omnicampus and select this week's assignment in the Omnicampus homework section.
#
# 3. Click the green button and select the CSV file to submit.
#
# 4. Click the gray button below to submit your answer.
#
# <br>
# Note:
#
# - You may submit as many times as you like, but **grading will only be done once after the deadline (it is not immediate grading).**
# - There is no leaderboard.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## How to answer
#
# For each $\fbox{　(　)　}$, please select the most appropriate option from the following choices, one by one.
#
# **Example Problem**
#
# In the lecture of the "University of Tokyo Global Consumer Intelligence Course," the goal is to broadly understand the basic theories of $\fbox{　(0)　}$ technology and to be able to apply them in the real world.
#
# 1. Language Model
# 2. Deep Learning
# 3. Reinforcement Learning
# 4. Data Science
#
# If the correct answer is "Data Science," you would answer 4 in the 0th box as follows:

# %% [markdown]
# ```python
# example[0] = 4
#
# ```

# %% [markdown]
# ## Deadline
# Wed, Jun 17 (11:00 UTC)

# %% [markdown]
# ## Quiz

# %% [markdown]
# **Q1 Select the most appropriate reason why SQL is considered important in data science.**
#
# 1. It is suitable for implementing machine learning algorithms.
# 2. It allows efficient manipulation and aggregation of large amounts of data.
# 3. It excels as a visualization tool.
# 4. It specializes in natural language processing.
#
# Answer: $\fbox{　(0)　}$

# %% [markdown]
# **Q2 Select the most appropriate feature of a relational database.**
#
# 1. Manages data in a hierarchical structure.
# 2. Stores data as key-value pairs.
# 3. Manages data in a two-dimensional table format.
# 4. Represents data relationships in a graph structure.
#
# Answer: $\fbox{　(1)　}$

# %% [markdown]
# **Q3 Select the most appropriate role of a "primary key" in a database.**
#
# 1. Data encryption
# 2. Unique identification of records
# 3. Joining tables
# 4. Data compression
#
# Answer: $\fbox{　(2)　}$

# %% [markdown]
# **Q4 Select the process that is not included in the ETL process.**
#
# 1. Perform data cleansing and standardization.
# 2. Collect data from multiple data sources.
# 3. Execute advanced analysis using the stored data.
# 4. Store the transformed data in the target system.
#
# Answer: $\fbox{　(3)　}$

# %% [markdown]
# **Q5 Select the most appropriate feature of the WHERE clause and HAVING clause in databases.**
#
# 1. WHERE clause is applied to data before aggregation, and HAVING clause is applied to data after aggregation.
# 2. WHERE clause is applied to data after aggregation, and HAVING clause is applied to data before aggregation.
# 3. WHERE clause is used together with the GROUP BY clause, and HAVING clause is used alone.
# 4. WHERE clause is only applied to numerical data, and HAVING clause is only applied to text data.
#
# Answer: $\fbox{　(4)　}$

# %% [markdown]
# **Q6 Select the most appropriate feature of a LEFT OUTER JOIN in databases.**
#
# 1. Includes all data from the left table in the result, even if there is no matching data in the right table.
# 2. Includes all data from the right table in the result, even if there is no matching data in the left table.
# 3. Includes only data that matches in both tables in the result.
# 4. Includes all data from both tables in the result.
#
# Answer: $\fbox{　(5)　}$

# %% [markdown]
# **Q7 Select the most appropriate clause that fits in the underlined part of the following SQL statement, in accordance with the (condition):**
#
# ```sql
# SELECT ______(*) FROM employees WHERE salary >= 300000;
# ```
#
# (Condition) Retrieve the number of employees from the employees table with salaries of 300,000 or more.
#
#
#
# 1.   SUM
# 2.   COUNT
# 3.   AVG
# 4.   NUMBER
#
# Answer: $\fbox{　(6)　}$

# %% [markdown]
# **Q8 Select the most appropriate clause that fits in the underlined part of the following SQL statement, in accordance with the (condition):**
#
# ```sql
# SELECT name, salary FROM employees ORDER BY salary _____ _____ 5;
#
# ```
# (Condition) Retrieve the names and salaries of employees from the employees table, and select the top 5 highest salaries.
#
# 1.   ASC, LIMIT
# 2.   DESC, LIMIT
# 3.   ASC, TOP
# 4.   DESC, TOP
#
# Answer: $\fbox{　(7)　}$

# %% [markdown]
# **Q9 Select the most appropriate description of the execution result of the following SQL statement.**
#
# ```sql
# SELECT product_name FROM products WHERE price > (SELECT AVG(price) FROM products);
# ```
# 1. Names of the most expensive products.
# 2. Names of products exceeding the average price.
# 3. Names of products below the average price.
# 4. Names of products with prices equal to the average price.
#
# Answer: $\fbox{　(8)　}$

# %% [markdown]
# **Q10 Select the most appropriate description of the execution result of the following SQL statement.**
# ```sql
# SELECT
#     product_name,
#     CASE
#         WHEN in_stock = 0 THEN 'Out of Stock'
#         WHEN in_stock < 10 THEN 'Low Stock'
#         ELSE 'In Stock'
#     END AS stock_status
# FROM products;
#
# ```
# 1. Stock status of products with no inventory
# 2. Stock status of products with the highest inventory
# 3. Names and inventory counts of each product
# 4. Names and inventory status of each product
#
# Answer: $\fbox{　(9)　}$

# %% [markdown]
# ## Solution
#
# Fill in the WRITE ME, then run all cells to create your `submission.csv`.

# %%
# Please do not modify this part
import numpy as np
import pandas as pd

NUM_EXAMPLE_QUESTIONS = 1
example = np.zeros(NUM_EXAMPLE_QUESTIONS, int)

NUM_QUESTIONS = 10
myanswer = np.zeros(NUM_QUESTIONS, int)

# %%
myanswer[0] = 2   # Q1: SQL efficiently manipulates and aggregates large data
myanswer[1] = 3   # Q2: Relational DB = two-dimensional table format
myanswer[2] = 2   # Q3: Primary key = unique identification of records
myanswer[3] = 3   # Q4: Advanced analysis is NOT part of ETL
myanswer[4] = 1   # Q5: WHERE before aggregation, HAVING after
myanswer[5] = 1   # Q6: LEFT OUTER JOIN includes all rows from left table
myanswer[6] = 2   # Q7: COUNT(*) counts employees
myanswer[7] = 2   # Q8: ORDER BY salary DESC LIMIT 5
myanswer[8] = 2   # Q9: Products exceeding average price
myanswer[9] = 4   # Q10: Names and inventory status of each product

# %%
# Create CSV
if not np.any(myanswer==0):
    submission = pd.Series(myanswer, name='label')
    submission.to_csv('submission.csv', header=True, index_label='id')
else:
    print('Error: please answer all of the questions')

# %%
print(myanswer)
# Out:
# [2 3 2 3 1 1 2 2 2 4]

# %%
from google.colab import files
files.download('submission.csv')
